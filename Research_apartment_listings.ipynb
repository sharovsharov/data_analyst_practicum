# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Саша :)
#
# Спасибо за работу на проекте
#
# стоит завершить фильтрацию редких значений в п. 2.4, учесть наличие пропусков, примеры оставил
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>Ответ студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ринат, привет!
#         Спасибо за комментарии, надеюсь своими комментариями отвечу на твои вопросы.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Саша :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии
#
# + завершить фильтрацию редких значений в п. 2.4, учесть наличие пропусков
# + пересчитать скорость продаж
# + добавить два графика в п. 4.3 и подправить расчет коэф. корреляции
#
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Саша :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# Задача научиться определять рыночую стоимость объектов недвижимости, установив параметры, что позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность. В работе используется архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# # Описание данных
# - **airports_nearest** — расстояние до ближайшего аэропорта в метрах (м)
# - **balcony** — число балконов
# - **ceiling_height** — высота потолков (м)
# - **cityCenters_nearest** — расстояние до центра города (м)
# - **days_exposition** — сколько дней было размещено объявление (от публикации до снятия)
# - **first_day_exposition** — дата публикации
# - **floor** — этаж
# - **floors_total** — всего этажей в доме
# - **is_apartment** — апартаменты (булев тип)
# - **kitchen_area** — площадь кухни в квадратных метрах (м²)
# - **last_price** — цена на момент снятия с публикации
# - **living_area** — жилая площадь в квадратных метрах (м²)
# - **locality_name** — название населённого пункта
# - **open_plan** — свободная планировка (булев тип)
# - **parks_around3000** — число парков в радиусе 3 км
# - **parks_nearest** — расстояние до ближайшего парка (м)
# - **ponds_around3000** — число водоёмов в радиусе 3 км
# - **ponds_nearest** — расстояние до ближайшего водоёма (м)
# - **rooms** — число комнат
# - **studio** — квартира-студия (булев тип)
# - **total_area** — общая площадь квартиры в квадратных метрах (м²)
# - **total_images** — число фотографий квартиры в объявлении

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from string import ascii_letters

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.info()
data.head(10)
stat_len_before = len(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Определим в каких столбцах есть пропуски

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(data)

# %% [markdown]
# #### Заполyим пропущенные значения там где возможно

# %%
# Высоту потолков 'ceiling_height' целесообразно заполнить мепдианным значением
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace=True)

# Исходя из того, что если продавец не указал число балконов, то, скорее всего, в его квартире их нет. 
# Заменяем пропущенные значения на 0
data['balcony'] = data['balcony'].fillna(value=0)
# Тоже самое проделываем с пропущенными значениями в столбцах с число водоёмов и парков в радиусе 3
data['parks_around3000'] = data['parks_around3000'].fillna(value=0)
# Приводим в целочисленный тип количество прудов. Заменяем пропущенные значения на 0
data['ponds_around3000'] = data['ponds_around3000'].fillna(value=0)
# Также заменим пропуски в 'days_exposition' и заменим тип данных
data['days_exposition'] = data['days_exposition'].fillna(0)

# Заменяем пропущенные значения в столбце 'is_apartment' на False (то есть 'нет')
data['is_apartment'] = data['is_apartment'].fillna(value=False)

# Удаляем записи, где отсутствует локация и количесвто этажей
data.dropna(subset=['locality_name'], inplace=True)
data.dropna(subset=['floors_total'], inplace=True)

# Повторрно проверим в каких столбцах остались пропуски
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                     0
# locality_name               0
# airports_nearest         5524
# cityCenters_nearest      5501
# parks_around3000            0
# parks_nearest           15535
# ponds_around3000            0
# ponds_nearest           14529
# days_exposition             0
# dtype: int64

# %% [markdown]
# #### Причины пропусков

# %% [markdown]
# Отсутствие данных может быть связано с несколькими причинами. Напрмер отсутствие какого-либо элемента квартиры. Например балкона вполне может не быть в квартире, и эти данные просто не заполнялись при сборе информации. Часть данных могла просто не собираться, напрмер, информация о том является ли квартира паартаментами. Пропуски адресе, могли быть связаны с потрей данных, или тем, что система не определяла адрес, который пытались занести, я сталкивался с такой проблемой с доставкой из интернет магазина. Также данные могли потеряться в процессе переноса или обработки данных.

# %% [markdown]
# #### Рассмотриv типы данных в каждом столбце:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %%
cols = ['floors_total', 'last_price', 'balcony', 'days_exposition', 'parks_around3000', 'ponds_around3000']
for col in cols:
    data[col] = data[col].astype(int)

# %%
# Переведем столбец с датой в формат даты без времени, т.к. время не указано
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# В столбцах 'floors_total', 'balcony', 'days_exposition', 'parks_around3000', 'ponds_around3000'  - заменили тип даннах на int, т.к. все эти данные - имеют целые значения
# 'last_price' - заменили на int, для удобства просмотра. Столбец с 'first_day_exposition' в формат даты.

# %% [markdown]
# #### Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты

# %%
# Вызовим уникальные значения в столбце с названиями населенных пунктов
data['locality_name'].sort_values().unique()
# Посчитаем их количество
len(data['locality_name'].sort_values().unique())
# Out:
# 364

# %%
#устраним неявные дубликаты
data['locality_name'] = data['locality_name'].str.replace('ё','e')
villages = ('городской посeлок', 'коттеджный посeлок', 'посeлок', 
        'посeлок городского типа','посeлок при железнодорожной станции'
        'пос. городского типа', 'коттеджный поселок', 'пос. городского типа',
        'пос. при железнодорожной станции', 'пос. имени', 'пос. станции',
        'поселок', 'пос. городского типа ')
for i in villages:
    data['locality_name'] = data['locality_name'].str.replace(i, 'пос.')
data['locality_name'].sort_values().unique()
# Out:
# /tmp/ipykernel_144/596263766.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['locality_name'] = data['locality_name'].str.replace(i, 'пос.')
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалeво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской пос. Большая Ижора', 'городской пос. Янино-1',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
# ...

# %%
# Убедимся что строк с уникальными значениями столо меньше
len(data['locality_name'].sort_values().unique())
# Out:
# 334

# %%
# Вызовим описание числовых данных
data.describe()
# Out:
#        total_images    last_price  total_area     rooms  ceiling_height  \
# count     23565.000     23565.000   23565.000 23565.000       23565.000
# mean          9.878   6540058.260      60.323     2.071           2.725
# std           5.681  10910934.722      35.657     1.079           0.991
# min           0.000     12190.000      12.000     0.000           1.000
# 25%           6.000   3400000.000      40.000     1.000           2.600
# 50%           9.000   4646000.000      52.000     2.000           2.650
# 75%          14.000   6790000.000      69.700     3.000           2.700
# max          50.000 763000000.000     900.000    19.000         100.000
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23565.000    21700.000 23565.000     21343.000 23565.000
# mean         10.676       34.455     5.878        10.561     0.594
# std           6.595       22.045     4.871         5.901     0.961
# ...

# %% [markdown]
# #### Найдем и устраните редкие и выбивающиеся значения

# %%
# с помощью цикла выведем диаграммы размаха по каждому интересуещему нас столбцу
cols = {'ceiling_height': (0, 10), 
        'total_area': (0, 350), 
        'rooms': (0, 8), 
        'floors_total': (0, 35), 
        'living_area': (0, 250), 
        'days_exposition': (0,2000),
       'last_price': (0, 30000000), 
       'kitchen_area': (0, 75)}
i = 0
fig, ax = plt.subplots(8, 1, figsize = (17,17))
for col, val in cols.items():
    ax[i] = data[[col]].boxplot(vert = False, ax = ax[i])
    ax[i].set_title(col)
    ax[i].set_xlim(val);
    i += 1
    
#     data[col].plot(kind='box', ylim=val)
#     plt.show()

# %%
# check
# для примера горизонтальный вид диаграммы размаха

fig, ax = plt.subplots(figsize = (17,2))
ax = data[['total_area']].boxplot(vert = False, ax =ax)
ax.set_title('Диаграмма размаха значений площади')
ax.set_xlim(0, 400);

# %% [markdown]
# ##### ceiling_height

# %%
# Посмотрим на все данные высоты потолка больше 25м.
# Скорее всего в данных не хватает запятой
data[data['ceiling_height']>25]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3148             14     2900000      75.000           2018-11-12      3
# 4876              7     3000000      25.000           2017-09-27      0
# 5246              0     2500000      54.000           2017-10-13      2
# 5669              4     4400000      50.000           2017-08-08      2
# 5807             17     8150000      80.000           2019-01-09      2
# 10773             8     3800000      58.000           2017-10-13      2
# 17857             1     3900000      56.000           2017-12-22      3
# 20478            11     8000000      45.000           2017-07-18      1
# 21377            19     4900000      42.000           2017-04-18      1
# 21824            20     2450000      44.000           2019-02-12      2
# 22336            19     9999000      92.400           2019-04-05      2
# 22869             0    15000000      25.000           2018-07-25      1
# ...

# %%
# Попраивм данные разделив на 10
data.loc[data['ceiling_height'] > 25, 'ceiling_height'] = data['ceiling_height'] / 10

# %%
data[data['ceiling_height'].isna()]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Потолки выше 4 местров в жилых помещениях встречаются не часто, удалим все значения выше 4 метров
data = data.query('ceiling_height < 4').copy()

# %%
# Проверим остались ли строки с высотой потолков выше 4 метров
data[data['ceiling_height']>4]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ##### total_area

# %%
# Избавимся от выбивающихся значений в остальных столбцах
data = data.query('total_area < 200').copy()

# %%
# Проверим остались ли строки с с общей площпдью более 250м метров
data[data['total_area']>200]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ##### rooms

# %%
# Глядя на диаграмму размаха квартиры с болишим чем 7 комнат кажутся выбросом, удалим эти значемия
data = data.query('rooms < 7').copy()

# %%
# Проверим остались ли квартиры с больше чем семь комнат
data[data['rooms']>7]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ##### floors_total

# %%
# Диаграмма размаха показывает, что количество домов с высотой больше 36 этажей прохоже на выброс
# Избавимся от этих данных
data = data.query('floors_total < 36').copy()

# %%
# Проверим остались ли дома выше 36 этажей
data[data['floors_total']>36]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ##### living_area

# %%
# После удаления редких данных 'living_area', еще раз посмотрим на данные жилой площади
data['living_area'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### days_exposition

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23223 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23223 non-null  int64
#  1   last_price            23223 non-null  int64
#  2   total_area            23223 non-null  float64
#  3   first_day_exposition  23223 non-null  datetime64[ns]
#  4   rooms                 23223 non-null  int64
#  5   ceiling_height        23223 non-null  float64
#  6   floors_total          23223 non-null  int64
#  7   living_area           21394 non-null  float64
#  8   floor                 23223 non-null  int64
#  9   is_apartment          23223 non-null  bool
#  10  studio                23223 non-null  bool
#  11  open_plan             23223 non-null  bool
#  12  kitchen_area          21043 non-null  float64
#  13  balcony               23223 non-null  int64
#  14  locality_name         23223 non-null  object
# ...

# %%
# Отфильтруем данные по 'days_exposition' оставим те, квартиры что продавались меньше 730 дней
l_before = len(data)
data = data[data['days_exposition']<730].copy()
l_after = len(data)
print('Процент отфильтрованных записей:', 1 - l_after / l_before * 1.0)
# Out:
# Процент отфильтрованных записей: 0.031089867803470672

# %%
len(data[data['days_exposition']>730])
# Out:
# 0

# %%
# check
data.shape[0]
# Out:
# 22501

# %% [markdown]
# ##### last_price

# %%
f, ax = plt.subplots(1, 2, figsize=(20, 5))
ax[0] = data['last_price'].hist(bins=1000, ax=ax[0])
ax[0].set_xlim(0, 20000000)
ax[1] = data[['last_price']].boxplot(vert=False, ax=ax[1])

# %%
# опираясь из графики столбца 'last_price' оставим квартиры стоимостью менее 50млн
data = data[data['last_price']<50000000].copy()

# %%
data[data['last_price']>50000000]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
data['last_price'].describe()
# Out:
# count      22451.000
# mean     5778049.453
# std      4484187.634
# min        12190.000
# 25%      3400000.000
# 50%      4590000.000
# 75%      6585000.000
# max     49900000.000
# Name: last_price, dtype: float64

# %% [markdown]
# ##### kitchen_area

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22451 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          22451 non-null  int64
#  1   last_price            22451 non-null  int64
#  2   total_area            22451 non-null  float64
#  3   first_day_exposition  22451 non-null  datetime64[ns]
#  4   rooms                 22451 non-null  int64
#  5   ceiling_height        22451 non-null  float64
#  6   floors_total          22451 non-null  int64
#  7   living_area           20673 non-null  float64
#  8   floor                 22451 non-null  int64
#  9   is_apartment          22451 non-null  bool
#  10  studio                22451 non-null  bool
#  11  open_plan             22451 non-null  bool
#  12  kitchen_area          20325 non-null  float64
#  13  balcony               22451 non-null  int64
#  14  locality_name         22451 non-null  object
# ...

# %%
# площадь кухни более 35 кв метров выглядит выбросом в данных, избавимся от них
data = data[data['kitchen_area']<35].copy()

# %%
# check
data.shape[0]
# Out:
# 20166

# %%
data[data['kitchen_area']>35]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20166 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20166 non-null  int64
#  1   last_price            20166 non-null  int64
#  2   total_area            20166 non-null  float64
#  3   first_day_exposition  20166 non-null  datetime64[ns]
#  4   rooms                 20166 non-null  int64
#  5   ceiling_height        20166 non-null  float64
#  6   floors_total          20166 non-null  int64
#  7   living_area           19765 non-null  float64
#  8   floor                 20166 non-null  int64
#  9   is_apartment          20166 non-null  bool
#  10  studio                20166 non-null  bool
#  11  open_plan             20166 non-null  bool
#  12  kitchen_area          20166 non-null  float64
#  13  balcony               20166 non-null  int64
#  14  locality_name         20166 non-null  object
# ...

# %%
# Удалим все данные больше 130м жилой площади
data = data[(data['living_area']<130) | (data['living_area'].isna())]

# %%
data[(data['living_area']<130) | (data['living_area'].isna())].isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area               401
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         4645
# cityCenters_nearest      4627
# parks_around3000            0
# parks_nearest           13379
# ponds_around3000            0
# ponds_nearest           12580
# days_exposition             0
# dtype: int64

# %%
# check
data.shape[0]
# Out:
# 20154

# %%
# Проверим остались ли квартиры с жилой площадью выше 130м
data[data['living_area']>130]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Основные редкие и выбивающиеся были найдены в столбце 'ceiling_height'. В данных были и выбросы и данные которые удалось исправить. Также убрали редкие данные с столюце 'floors_total' и 'rooms'. Данные из столбцов с общей и жилой площадью оставили без изменений.

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_aea09_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aea09_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_aea09_row0_col0" class="data row0 col0" >20,154.00</td>
#                         <td id="T_aea09_row0_col1" class="data row0 col1" >20,154.00</td>
# ...

# %%
# check
data.rooms.value_counts().to_frame()
# Out:
#    rooms
# 1   6990
# 2   6951
# 3   5024
# 4    937
# 5    206
# 6     46

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3));

# %%
# check
data.total_area.hist(bins = 150, figsize = (15,3), range = (180,500));

# %%
# check
data.total_area.value_counts(bins =20)
# Out:
# (41.735, 50.98]      4179
# (32.49, 41.735]      4042
# (50.98, 60.225]      3334
# (60.225, 69.47]      2234
# (69.47, 78.715]      1655
# (23.245, 32.49]      1611
# (78.715, 87.96]      1051
# (87.96, 97.205]       676
# (97.205, 106.45]      417
# (106.45, 115.695]     275
# (115.695, 124.94]     172
# (124.94, 134.185]     138
# (143.43, 152.675]      91
# (134.185, 143.43]      84
# (161.92, 171.165]      54
# (152.675, 161.92]      49
# (171.165, 180.41]      30
# (13.814, 23.245]       25
# (180.41, 189.655]      22
# (189.655, 198.9]       15
# Name: total_area, dtype: int64

# %%
stat_len_after = len(data)

# %%
print('% отфильтрованных записей после обработки:', 1 - stat_len_after / stat_len_before)
# Out:
# % отфильтрованных записей после обработки: 0.14958437064855057

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.01, .5, .90, .9976])  
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_c48cd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c48cd_level0_row0" class="row_heading level0 row0" >0.01</th>
#                         <td id="T_c48cd_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_c48cd_row0_col1" class="data row0 col1" >29.00</td>
# ...

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир


(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_7507a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7507a_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_7507a_row0_col0" class="data row0 col0" >20,154.00</td>
#                         <td id="T_7507a_row0_col1" class="data row0 col1" >20,154.00</td>
# ...

# %%
# check
data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0,5));

# %%
data[data['kitchen_area'] >50]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
data['kitchen_area_coef'] = data['kitchen_area'] / data['total_area']
print(data['kitchen_area_coef'].mean(), data['kitchen_area_coef'].median())
data['kitchen_area_coef'].hist()
# Out:
# 0.1868604530185814 0.17253649063459253
# <AxesSubplot:>

# %%
data[data['kitchen_area_coef'] > 0.6][['total_area', 'kitchen_area']]
# Out:
#        total_area  kitchen_area
# 696        34.690        23.430
# 1326       52.000        32.000
# 1407       24.600        18.200
# 7755       20.670        14.950
# 11579      33.000        26.000
# 20994      50.600        31.000

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_50952_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_50952_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_50952_row0_col0" class="data row0 col0" >20,154.00</td>
#                         <td id="T_50952_row0_col1" class="data row0 col1" >20,154.00</td>
# ...

# %%
# check
data.hist(column = 'kitchen_area', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0,40);

# %%
# check
data.hist(column = 'ceiling_height', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0,20);

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0.1,5))
plt.ylim(0,20);

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
# Добавим столбец с ценами одного квадратного метра
data['price_per_m'] = data['last_price']/data['total_area']
# Добавим столбец c днем недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday
# Месяцем
data['month_exposition'] = data['first_day_exposition'].dt.month
# Годом
data['year_exposition'] = data['first_day_exposition'].dt.year

# %%
# Создадим функцию категоризации по этажам
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'

# Добавим столбец с категориями этажности
data['floor_category'] = data.apply(floor_category, axis = 1)

# %%
# Переведем расстояние до центра города в м и округлим до целого значения
data['cityCenters_nearest_km'] = data['cityCenters_nearest']/1000
data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].fillna(value=0).astype(int)

# %%
# Проверим появились ли новые столбцы в данных
data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000     108.000           2019-03-07      3
# 1              7     3350000      40.400           2018-12-04      1
# 2             10     5196000      56.000           2015-08-20      2
# 5             10     2890000      30.400           2018-09-10      1
# 6              6     3700000      37.300           2017-11-02      1
# 7              5     7915000      71.600           2019-04-18      2
# 8             20     2900000      33.160           2018-05-23      1
# 9             18     5400000      61.000           2017-02-26      3
# 10             5     5050000      39.600           2017-11-16      1
# 11             9     3300000      44.000           2018-08-27      2
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.700            16       51.000      8         False  ...
# ...

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Общая площадь

# %%
# Данные в столбце 'total_area'
data.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, range = (0, 200))
data['total_area'].describe()
# Out:
# count   20154.000
# mean       57.386
# std        24.489
# min        14.000
# 25%        40.000
# 50%        51.400
# 75%        67.900
# max       198.900
# Name: total_area, dtype: float64

# %% [markdown]
# Большая часть квартир имеет площадь от 30 до 75м

# %% [markdown]
# #### Жилая площадь

# %%
# Данные в столбце 'living_area'
data.plot(y = 'living_area', kind = 'hist', bins = 50, grid=True, range = (0, 250))
data['living_area'].describe()
# Out:
# count   19753.000
# mean       32.852
# std        16.458
# min         2.000
# 25%        18.600
# 50%        30.000
# 75%        42.000
# max       128.000
# Name: living_area, dtype: float64

# %% [markdown]
# Большая часть значений сосредоточена в промежутке от 20 до 50 метров.
# Значения больше 100 метров единичны.

# %% [markdown]
# #### Площадь кухни

# %%
# Данные в столбце 'kitchen_area'
data.plot(y = 'kitchen_area', kind = 'hist', bins = 50, grid=True, range = (5,90))
data['kitchen_area'].describe()
# Out:
# count   20154.000
# mean       10.017
# std         4.219
# min         1.300
# 25%         7.000
# 50%         9.000
# 75%        11.558
# max        34.800
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Большая часть кварьтир имеет площпдь кухни до 20 квадратных метров

# %% [markdown]
# #### Цена объекта

# %%
# Данные в столбце 'last_price'
data.plot(y = 'last_price', kind = 'hist', bins = 150, grid=True, range = (0,15000000))
data['last_price'].describe()
# Out:
# count      20154.000
# mean     5712202.307
# std      4212212.615
# min       430000.000
# 25%      3450000.000
# 50%      4600000.000
# 75%      6550000.000
# max     49900000.000
# Name: last_price, dtype: float64

# %% [markdown]
# Большинство квартир в выборке стоят около 6 миллионов.
# Но есть квартиры дороже в несколько раз, что неудивительно для мегаполиса.

# %% [markdown]
# #### Количество комнат

# %%
# Данные в столбце 'rooms'
data.plot(y = 'rooms', kind = 'hist', bins = 10, grid=True, range = (0,10))
data['rooms'].describe()
# Out:
# count   20154.000
# mean        2.035
# std         0.954
# min         1.000
# 25%         1.000
# 50%         2.000
# 75%         3.000
# max         6.000
# Name: rooms, dtype: float64

# %% [markdown]
# Большая часть квартир имеет от 1 до 4 комант, но есть и квартиры с 6 комнаталми комнат. Думаю что это особенность Санкт Петербурга с его большим количеством коммуналных квартир.

# %% [markdown]
# #### Высота потолков

# %%
# Данные в столбце 'ceiling_height'
data.plot(y = 'ceiling_height', kind = 'hist', bins = 10, grid = True, range = (0,10))
data['ceiling_height'].describe()
# Out:
# count   20154.000
# mean        2.684
# std         0.191
# min         1.000
# 25%         2.600
# 50%         2.650
# 75%         2.700
# max         3.980
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Высота потолков от 2 до 3 метров.

# %% [markdown]
# #### Этаж квартиры

# %%
# Данные в столбце 'floor'
data.plot(y = 'floor', kind = 'hist', bins = 10, grid=True, range = (0,35))
data['floor'].describe()
# Out:
# count   20154.000
# mean        5.870
# std         4.831
# min         1.000
# 25%         2.000
# 50%         4.000
# 75%         8.000
# max        33.000
# Name: floor, dtype: float64

# %% [markdown]
# Большая часть квартир находится с 1 по 10 этаж

# %% [markdown]
# #### Тип этажа квартиры («первый», «последний», «другой»)

# %%
# Данные в столбце 'floor_category'
data['floor_category'].value_counts()
# Out:
# другой       14860
# последний     2821
# первый        2473
# Name: floor_category, dtype: int64

# %% [markdown]
# Большая часть квартир находятся в категории «другой», то есть располагаются не на первом и не на последнем этажах.

# %% [markdown]
# #### Общее количество этажей в доме

# %%
# Данные в столбце 'floors_total'
data.plot(y = 'floors_total', kind = 'hist', bins = 80, grid=True, range = (0,50))
data['floors_total'].describe()
# Out:
# count   20154.000
# mean       10.666
# std         6.532
# min         1.000
# 25%         5.000
# 50%         9.000
# 75%        16.000
# max        35.000
# Name: floors_total, dtype: float64

# %% [markdown]
# Большая часть квартир находится в домах до 20 этажей

# %% [markdown]
# #### Расстояние до центра города в метрах

# %%
# Данные в столбце 'cityCenters_nearest'
data.plot(y = 'cityCenters_nearest', kind = 'hist', bins = 10, grid=True, range = (0,60000))
data['cityCenters_nearest'].describe()
# Out:
# count   15527.000
# mean    14483.115
# std      8568.681
# min       181.000
# 25%      9817.500
# 50%     13252.000
# 75%     16379.000
# max     65952.000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Большинство квартир находится на расстоянии до 12 км от центра города

# %% [markdown]
# #### Расстояние до ближайшего аэропорта

# %%
# Данные в столбце 'airports_nearest'
data.plot(y = 'airports_nearest', kind = 'hist', bins = 10, grid=True, range = (0,90000))
data['airports_nearest'].describe()
# Out:
# count   15509.000
# mean    28895.359
# std     12780.450
# min         0.000
# 25%     18402.000
# 50%     26996.000
# 75%     37434.000
# max     84853.000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Большинство квартир находится на расстоянии до 42 км от аэропорта

# %% [markdown]
# #### Расстояние до ближайшего парка

# %%
# Данные в столбце 'parks_nearest'
data.plot(y = 'parks_nearest', kind = 'hist', bins = 10, grid=True, range = (0,3200))
data['parks_nearest'].describe()
# Out:
# count   6775.000
# mean     488.827
# std      336.065
# min        1.000
# 25%      288.000
# 50%      456.000
# 75%      612.000
# max     3190.000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Большинство квартир находится на расстоянии до 1 км ближайшего парка

# %% [markdown]
# #### День публикации объявления

# %%
data['weekday_exposition'].value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большая часть сделок по продаже квартир происходит во вторник, четверг и пятницу

# %% [markdown]
# #### Месяц публикации объявления

# %%
data['month_exposition'].value_counts().sort_index().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Самые активные месяцы продаж: февраль, март, ноябрь
# Минимальные по продажам: январь и май

# %% [markdown]
# #### Параметр days_exposition

# %%
# Как быстро продавались квартиры 'days_exposition'
data[data['days_exposition']>0].plot(y = 'days_exposition', kind = 'hist', bins = 20, grid=True, range = (0,1600))
print('Cреднее:', data['days_exposition'].mean())
print('Медиана:', data['days_exposition'].median())
# Out:
# Cреднее: 131.77934901260295
# Медиана: 72.0

# %%
data[data['days_exposition']>0]['days_exposition'].describe()
# Out:
# count   17324.000
# mean      153.306
# std       156.930
# min         1.000
# 25%        42.000
# 50%        94.000
# 75%       211.000
# max       729.000
# Name: days_exposition, dtype: float64

# %% [markdown]
# 50% квартир продается в быстрее 94 дней. Быстрой продажей можно считать продажи, которые происходит быстрее 42 дней, долгими — больше 211 дней.

# %% [markdown]
# #### Зависимость цены от параметров

# %%
sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = data[['last_price', 'total_area',
       'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
       'kitchen_area','weekday_exposition',
       'month_exposition', 'year_exposition', 'floor_category',
       ]].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition', 'kitchen_area_coef', 'price_per_m',
#        'weekday_exposition', 'month_exposition', 'year_exposition',
#        'floor_category', 'cityCenters_nearest_km'],
#       dtype='object')

# %%
data.pivot_table(index='floor', values=['last_price'], aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='floor'>

# %% [markdown]
# ##### Зависимость цены от площади

# %%
(
    data.pivot_table(index='total_area', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и общей площади:','\n')
data[['total_area', 'last_price']].corr(),'\n'
# Out:
# Корреляция цены и общей площади:
# (            total_area  last_price
#  total_area       1.000       0.760
#  last_price       0.760       1.000,
#  '\n')

# %% [markdown]
# Высокий уровень корреляции между общей площадью и стоимостью квартиры

# %% [markdown]
# ##### Зависимость цены от жилой площади

# %%
(
    data.pivot_table(index='living_area', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и жилой площади:','\n')
data[['living_area', 'last_price']].corr(),'\n'
# Out:
# Корреляция цены и жилой площади:
# (             living_area  last_price
#  living_area        1.000       0.656
#  last_price         0.656       1.000,
#  '\n')

# %% [markdown]
# Корреляция немного ниже, чем в случае с общей площадью

# %% [markdown]
# ##### Зависимость цены от площади кухни

# %%
(
    data.pivot_table(index='kitchen_area', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и площади кухни:','\n')
data[['kitchen_area', 'last_price']].corr(),'\n'
# Out:
# Корреляция цены и площади кухни:
# (              kitchen_area  last_price
#  kitchen_area         1.000       0.555
#  last_price           0.555       1.000,
#  '\n')

# %% [markdown]
# Зависимость цены от площади кухни еще немного ниже чем от прудыдущих параметров

# %% [markdown]
# ##### Зависимость цены от удалённости от центра

# %%
(
    data.pivot_table(index='cityCenters_nearest', values='last_price')
    .plot(grid=True, style='o', figsize=(5, 5))
)
plt.show()
print('Корреляция цены и удалённости от центра:','\n')
print(data[['cityCenters_nearest', 'last_price']].corr(),'\n')
# Out:
# Корреляция цены и удалённости от центра:
#
#                      cityCenters_nearest  last_price
# cityCenters_nearest                1.000      -0.331
# last_price                        -0.331       1.000

# %% [markdown]
# Чем квартира дальше от центра тем ниже ее стоимость

# %% [markdown]
# ##### Зависимость цены от числа комнат

# %%
(
    data.query('rooms > 0').pivot_table(index='rooms', values='last_price', aggfunc='median')
    .plot(kind='bar', grid=True, figsize=(5, 5))
)
plt.show()
print('Корреляция цены и числа комнат:','\n')
print(data[['rooms', 'last_price']].corr(),'\n')
# Out:
# Корреляция цены и числа комнат:
#
#             rooms  last_price
# rooms       1.000       0.468
# last_price  0.468       1.000

# %% [markdown]
# Чем больше комнат, тем выше стоимость квартиры

# %% [markdown]
# ##### Зависимость цены от этажа

# %%
(
    data.pivot_table(index='floor_category', values='last_price', aggfunc='median')
    .plot(kind='bar', grid=True, style='o-', figsize=(5, 5))
)
plt.show()

# %% [markdown]
# ##### Зависимость цены от дня, месяца и года публикации объявления

# %%
for columns in ['weekday_exposition', 'month_exposition', 'year_exposition']:
    (
    data.pivot_table(index=columns, values='last_price', aggfunc='median')
    .plot(figsize=(5, 5), grid=True)
    )
    plt.show()

# %% [markdown]
# Наивысшая стоиомсть у тех объявлений, которые публикуются во вторник, наименьшая в выходные.
# Апрель — месяц самых дорогих объявления

# %%
# Сравниваем среднюю стоимость квадратного метра в топ-10 городов по числу объявлений
high_price_10 = data['locality_name'].value_counts().head(10)
high_price_10 = data.query('locality_name in (@high_price_10.index)').pivot_table(values='price_per_m', index='locality_name')
high_price_10 = high_price_10.astype(int)
high_price_10.sort_values('price_per_m', ascending=False)
# Out:
#                  price_per_m
# locality_name
# Санкт-Петербург       110656
# Пушкин                102699
# деревня Кудрово        92280
# пос. Парголово         90527
# пос. Мурино            85326
# пос. Шушары            78406
# Колпино                75051
# Всеволожск             69074
# Гатчина                68786
# Выборг                 58516

# %%
spb_price_center = data[data['locality_name'] == 'Санкт-Петербург']
f, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0] = (
    spb_price_center.pivot_table(index='cityCenters_nearest_km', values='last_price', aggfunc='median')
    .reset_index()
    .plot(kind='scatter', x= 'cityCenters_nearest_km', y='last_price', grid=True, 
          ax=ax[0])
)
ax[1] = (
    spb_price_center.pivot_table(index='cityCenters_nearest_km', values='last_price', aggfunc='median')
    .plot(grid=True, ax=ax[1])
)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
spb_price_center.pivot_table(index='cityCenters_nearest_km', values='last_price', aggfunc='median').reset_index()
# Out:
#     cityCenters_nearest_km  last_price
# 0                        0     8600000
# 1                        1     9900000
# 2                        2     9000000
# 3                        3     8120000
# 4                        4     9175000
# 5                        5     8499000
# 6                        6     7300000
# 7                        7     7250000
# 8                        8     6460000
# 9                        9     5030000
# 10                      10     4999000
# 11                      11     4999000
# 12                      12     5040000
# 13                      13     5200000
# 14                      14     4900000
# 15                      15     4850000
# 16                      16     4650000
# 17                      17     4400000
# 18                      18     4500000
# 19                      19     4500000
# 20                      20     5933867
# 21                      21     4697500
# 22                      22     5000000
# ...

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# На стоимость объекта в большей степени влияет общая площадь квартиры,
# далее жилая площадь, площадь кухни и количесвто комнат.
# Чем квартира дальше от центра, тем ее стоимость ниже, что ожидаемо.
# Первый и последний этажи имеют меньшую стоимость чем другие.
#
# 50% квартир продается в быстрее 94 дней. Быстрой продажей можно считать продажи, которые происходит быстрее 42 дней, долгими — больше 211 дней.
#
# Самая высокая сердняя цена квадратного местра в Санкт—Петербурге — 114868р
# Самая низкая в Выборге — 58141р

# %% [markdown]
# ### Бонус

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [X]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
